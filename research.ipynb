# %%
import os
import time
from datetime import datetime, timedelta
from itertools import islice

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import requests

# ────────────────────────────────────────────────────────────────────────────────
# Config
# ────────────────────────────────────────────────────────────────────────────────
COINGECKO_BASE = "https://api.coingecko.com/api/v3"
DATA_DIR = "./data"      # minute‑klines
os.makedirs(DATA_DIR, exist_ok=True)

pd.options.display.float_format = "{:,}".format  # ditch scientific notation

# ────────────────────────────────────────────────────────────────────────────────
# Helper utils
# ────────────────────────────────────────────────────────────────────────────────

def _chunks(iterable, n):
    it = iter(iterable)
    while chunk := list(islice(it, n)):
        yield chunk

# ────────────────────────────────────────────────────────────────────────────────
# Binance (pairs + klines)
# ────────────────────────────────────────────────────────────────────────────────

def get_binance_us_symbols():
    """Return every USDT trading pair listed on Binance US (e.g. BTCUSDT)."""
    r = requests.get("https://api.binance.us/api/v3/exchangeInfo", timeout=10)
    r.raise_for_status()
    symbols = r.json()["symbols"]
    return [s["symbol"] for s in symbols if s["quoteAsset"] == "USDT" and s["status"] == "TRADING"]


def fetch_and_save_klines(pairs, supply_map, interval="1m", days=14):
    """Download klines and compute minute‑level market_cap = close * circulating_supply.

    Args:
        pairs (list[str]): Binance pairs like BTCUSDT
        supply_map (dict): {SYMBOL: circulating_supply}
        interval (str): Binance kline interval
        days (int): look‑back window

    Returns:
        dict: {PAIR: parquet_path_written}
    """
    base_url = "https://api.binance.us"
    out = {}

    for pair in pairs:
        sym = pair.replace("USDT", "").upper()
        supply = supply_map.get(sym)
        if supply is None or pd.isna(supply):
            print(f"⚠️  No circulating_supply for {sym}; market_cap will be NA")
        print(f"⏳  Fetching klines {pair}…")
        end_ms = int(time.time() * 1000)
        start_ms = end_ms - days * 24 * 60 * 60 * 1000
        rows = []
        while start_ms < end_ms:
            try:
                resp = requests.get(
                    f"{base_url}/api/v3/klines",
                    params={
                        "symbol": pair,
                        "interval": interval,
                        "startTime": start_ms,
                        "endTime": end_ms,
                        "limit": 1000,
                    },
                    timeout=10,
                )
                resp.raise_for_status()
                batch = resp.json()
                if not batch:
                    break
                rows.extend(batch)
                start_ms = batch[-1][0] + 1
                time.sleep(0.05)
            except Exception as e:
                print(f"❌  Error klines {pair}: {e}")
                break

        if not rows:
            print(f"⚠️  No klines for {pair}")
            continue

        df = pd.DataFrame(
            rows,
            columns=[
                "open_time", "open", "high", "low", "close", "volume",
                "close_time", "qav", "num_trades", "taker_base",
                "taker_quote", "ignore",
            ],
        )
        df["open_time"] = pd.to_datetime(df["open_time"], unit="ms")
        df.set_index("open_time", inplace=True)
        df = df[["open", "high", "low", "close", "volume"]].astype(float)

        # compute minute‑level market cap via supply * close_price
        if supply is not None and not pd.isna(supply):
            df["market_cap"] = df["close"] * supply
        else:
            df["market_cap"] = pd.NA

        fname = os.path.abspath(os.path.join(DATA_DIR, f"{pair.lower()}_{interval}_last{days}d.parquet"))
        pq.write_table(pa.Table.from_pandas(df), fname)
        out[pair.upper()] = fname
        print(f"✅  {fname}  ({len(df):,} rows | market_cap computed)")
    return out

# ────────────────────────────────────────────────────────────────────────────────
# CoinGecko (symbol map, current market data)
# ────────────────────────────────────────────────────────────────────────────────

_SYMBOL_TO_ID = None

def _load_symbol_map():
    global _SYMBOL_TO_ID
    if _SYMBOL_TO_ID is None:
        print("🔄  Loading CoinGecko symbol list…")
        resp = requests.get(f"{COINGECKO_BASE}/coins/list", timeout=30)
        resp.raise_for_status()
        _SYMBOL_TO_ID = {c["symbol"].upper(): c["id"] for c in resp.json()}
    return _SYMBOL_TO_ID


def get_coingecko_ids(symbols):
    mapping = _load_symbol_map()
    return {s: mapping.get(s) for s in symbols}


def fetch_current_market_data(ids):
    """Return list of market data dicts from /coins/markets for given coin IDs."""
    results = []
    for chunk in _chunks(list(ids), 250):
        r = requests.get(
            f"{COINGECKO_BASE}/coins/markets",
            params={"vs_currency": "usd", "ids": ",".join(chunk), "price_change_percentage": "24h"},
            timeout=20,
        )
        if r.status_code == 429:
            print("⏳  Markets rate‑limited — sleep 60 s…")
            time.sleep(60)
            r = requests.get(
                f"{COINGECKO_BASE}/coins/markets",
                params={"vs_currency": "usd", "ids": ",".join(chunk), "price_change_percentage": "24h"},
                timeout=20,
            )
        r.raise_for_status()
        results.extend(r.json())
    return results

# ────────────────────────────────────────────────────────────────────────────────
# Master DataFrame
# ────────────────────────────────────────────────────────────────────────────────

def build_master_dataframe(pairs, market_data, kline_paths):
    md_df = pd.DataFrame(market_data)
    md_df["symbol"] = md_df["symbol"].str.upper()

    base_syms = [p.replace("USDT", "") for p in pairs]
    df = pd.DataFrame({"binance_pair": pairs, "base_symbol": base_syms}).merge(
        md_df, how="left", left_on="base_symbol", right_on="symbol"
    )

    df["klines_parquet"] = df["binance_pair"].map(kline_paths)

    keep = [
        "binance_pair", "name", "symbol", "current_price", "market_cap", "klines_parquet",
        "circulating_supply", "total_supply", "max_supply",
    ]
    return df[keep].sort_values("market_cap", ascending=False)

# ────────────────────────────────────────────────────────────────────────────────
# Main
# ────────────────────────────────────────────────────────────────────────────────

if __name__ == "__main__":
    DAYS = 14

    # 1 Binance pairs
    pairs = get_binance_us_symbols()

    # 2 CoinGecko IDs & current market data (includes circulating_supply)
    base_syms = [p.replace("USDT", "") for p in pairs]
    symbol_to_id = get_coingecko_ids(base_syms)
    market_data = fetch_current_market_data([cid for cid in symbol_to_id.values() if cid])

    # build supply map for quick lookup
    supply_map = {d["symbol"].upper(): d.get("circulating_supply") for d in market_data}

    # 3 Minute klines with computed market_cap column
    kline_paths = fetch_and_save_klines(pairs, supply_map, days=DAYS)

    # 4 Merge summary
    master_df = build_master_dataframe(pairs, market_data, kline_paths)
    master_path = "binance_coingecko_market_caps.parquet"
    master_df.to_parquet(master_path, index=False)

    print(master_df.head())
    print(f"📝  Master saved → {master_path}")
# Out:
# 🔄  Loading CoinGecko symbol list…
# ⚠️  No circulating_supply for BTC; market_cap will be NA
# ⏳  Fetching klines BTCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\btcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ETH; market_cap will be NA
# ⏳  Fetching klines ETHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ethusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for XRP; market_cap will be NA
# ⏳  Fetching klines XRPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\xrpusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BCHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bchusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines LTCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ltcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for BNB; market_cap will be NA
# ⏳  Fetching klines BNBUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bnbusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ADAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\adausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for BAT; market_cap will be NA
# ⏳  Fetching klines BATUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\batusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ETCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\etcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines XLMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\xlmusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ZRXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\zrxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for DOGE; market_cap will be NA
# ⏳  Fetching klines DOGEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\dogeusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ATOMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\atomusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines NEOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\neousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines VETUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\vetusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines QTUMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\qtumusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ONTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ontusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines KNCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\kncusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines VTHOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\vthousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines COMPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\compusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines MKRUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\mkrusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ONE; market_cap will be NA
# ⏳  Fetching klines ONEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\oneusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BANDUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bandusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for STORJ; market_cap will be NA
# ⏳  Fetching klines STORJUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\storjusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for UNI; market_cap will be NA
# ⏳  Fetching klines UNIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\uniusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for SOL; market_cap will be NA
# ⏳  Fetching klines SOLUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\solusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines EGLDUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\egldusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines PAXGUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\paxgusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for OXT; market_cap will be NA
# ⏳  Fetching klines OXTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\oxtusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ZEN; market_cap will be NA
# ⏳  Fetching klines ZENUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\zenusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines FILUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\filusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines AAVEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\aaveusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines GRTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\grtusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for SHIB; market_cap will be NA
# ⏳  Fetching klines SHIBUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\shibusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines CRVUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\crvusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines AXSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\axsusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines AVAXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\avaxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines CTSIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ctsiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for DOT; market_cap will be NA
# ⏳  Fetching klines DOTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\dotusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines YFIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\yfiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines 1INCHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\1inchusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for USDC; market_cap will be NA
# ⏳  Fetching klines USDCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\usdcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for MANA; market_cap will be NA
# ⏳  Fetching klines MANAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\manausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ALGOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\algousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LINK; market_cap will be NA
# ⏳  Fetching klines LINKUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\linkusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines EOSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\eosusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ZECUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\zecusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ENJUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\enjusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines NEARUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\nearusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines SUSHIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\sushiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines LRCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\lrcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines LPTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\lptusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines NMRUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\nmrusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines SLPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\slpusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines CHZUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\chzusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for OGN; market_cap will be NA
# ⏳  Fetching klines OGNUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ognusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines GALAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\galausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for TLM; market_cap will be NA
# ⏳  Fetching klines TLMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\tlmusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines SNXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\snxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for AUDIO; market_cap will be NA
# ⏳  Fetching klines AUDIOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\audiousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ENSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ensusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines REQUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\requsdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for APE; market_cap will be NA
# ⏳  Fetching klines APEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\apeusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines FLUXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\fluxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines COTIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\cotiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for VOXEL; market_cap will be NA
# ⏳  Fetching klines VOXELUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\voxelusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines RLCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\rlcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BICOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bicousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines API3USDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\api3usdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BNTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bntusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines IMXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\imxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for FLOW; market_cap will be NA
# ⏳  Fetching klines FLOWUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\flowusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for GTC; market_cap will be NA
# ⏳  Fetching klines GTCUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\gtcusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines THETAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\thetausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines TFUELUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\tfuelusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines OCEANUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\oceanusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LAZIO; market_cap will be NA
# ⏳  Fetching klines LAZIOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\laziousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for SANTOS; market_cap will be NA
# ⏳  Fetching klines SANTOSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\santosusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ALPINE; market_cap will be NA
# ⏳  Fetching klines ALPINEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\alpineusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for PORTO; market_cap will be NA
# ⏳  Fetching klines PORTOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\portousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines CELRUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\celrusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines SKLUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\sklusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines WAXPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\waxpusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LTO; market_cap will be NA
# ⏳  Fetching klines LTOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ltousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines FETUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\fetusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LOKA; market_cap will be NA
# ⏳  Fetching klines LOKAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\lokausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ICPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\icpusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines TUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\tusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for OP; market_cap will be NA
# ⏳  Fetching klines OPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\opusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ROSE; market_cap will be NA
# ⏳  Fetching klines ROSEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\roseusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for CELO; market_cap will be NA
# ⏳  Fetching klines CELOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\celousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines KDAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\kdausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines KSMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ksmusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ACHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\achusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for SYS; market_cap will be NA
# ⏳  Fetching klines SYSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\sysusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for RAD; market_cap will be NA
# ⏳  Fetching klines RADUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\radusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ILVUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ilvusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LDO; market_cap will be NA
# ⏳  Fetching klines LDOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ldousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for RARE; market_cap will be NA
# ⏳  Fetching klines RAREUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\rareusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines LSKUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\lskusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines DGBUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\dgbusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for REEF; market_cap will be NA
# ⏳  Fetching klines REEFUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\reefusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ALICE; market_cap will be NA
# ⏳  Fetching klines ALICEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\aliceusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for FORTH; market_cap will be NA
# ⏳  Fetching klines FORTHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\forthusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ASTR; market_cap will be NA
# ⏳  Fetching klines ASTRUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\astrusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for BTRST; market_cap will be NA
# ⏳  Fetching klines BTRSTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\btrstusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for SAND; market_cap will be NA
# ⏳  Fetching klines SANDUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\sandusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BALUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\balusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines GLMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\glmusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for CLV; market_cap will be NA
# ⏳  Fetching klines CLVUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\clvusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines QNTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\qntusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines STGUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\stgusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for AXL; market_cap will be NA
# ⏳  Fetching klines AXLUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\axlusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines KAVAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\kavausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines APTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\aptusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for MASK; market_cap will be NA
# ⏳  Fetching klines MASKUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\maskusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for BOSON; market_cap will be NA
# ⏳  Fetching klines BOSONUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bosonusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines PONDUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\pondusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for JAM; market_cap will be NA
# ⏳  Fetching klines JAMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\jamusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for TRAC; market_cap will be NA
# ⏳  Fetching klines TRACUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\tracusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines PROMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\promusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines DIAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\diausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for LOOM; market_cap will be NA
# ⏳  Fetching klines LOOMUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\loomusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for STMX; market_cap will be NA
# ⏳  Fetching klines STMXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\stmxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines POLYXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\polyxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines IOSTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\iostusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ARB; market_cap will be NA
# ⏳  Fetching klines ARBUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\arbusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for FLOKI; market_cap will be NA
# ⏳  Fetching klines FLOKIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\flokiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines XECUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\xecusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines BLURUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\blurusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ANKRUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ankrusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for DAI; market_cap will be NA
# ⏳  Fetching klines DAIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\daiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for DASH; market_cap will be NA
# ⏳  Fetching klines DASHUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\dashusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines HBARUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\hbarusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ICXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\icxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines IOTAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\iotausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines RVNUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\rvnusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for XNO; market_cap will be NA
# ⏳  Fetching klines XNOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\xnousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines XTZUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\xtzusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ZILUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\zilusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ORBSUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\orbsusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for ADX; market_cap will be NA
# ⏳  Fetching klines ADXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\adxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for FORT; market_cap will be NA
# ⏳  Fetching klines FORTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\fortusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines SUIUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\suiusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ONGUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\ongusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines GUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\gusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines RENDERUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\renderusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for BONK; market_cap will be NA
# ⏳  Fetching klines BONKUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\bonkusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for MAGIC; market_cap will be NA
# ⏳  Fetching klines MAGICUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\magicusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for PEPE; market_cap will be NA
# ⏳  Fetching klines PEPEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\pepeusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for WIF; market_cap will be NA
# ⏳  Fetching klines WIFUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\wifusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines IOTXUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\iotxusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for PNUT; market_cap will be NA
# ⏳  Fetching klines PNUTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\pnutusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines PENGUUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\penguusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for POL; market_cap will be NA
# ⏳  Fetching klines POLUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\polusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for TRUMP; market_cap will be NA
# ⏳  Fetching klines TRUMPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\trumpusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for NEIRO; market_cap will be NA
# ⏳  Fetching klines NEIROUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\neirousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines EIGENUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\eigenusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines MEUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\meusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for D; market_cap will be NA
# ⏳  Fetching klines DUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\dusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines METISUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\metisusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines JUPUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\jupusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for S; market_cap will be NA
# ⏳  Fetching klines SUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\susdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines JTOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\jtousdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines ORCAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\orcausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⚠️  No circulating_supply for DATA; market_cap will be NA
# ⏳  Fetching klines DATAUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\datausdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines VIRTUALUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\virtualusdt_1m_last14d.parquet  (20,160 rows | market_cap computed)
# ⏳  Fetching klines AIXBTUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\aixbtusdt_1m_last14d.parquet  (13,352 rows | market_cap computed)
# ⏳  Fetching klines KAITOUSDT…
# ✅  C:\Users\saber\OneDrive\Documents\GitHub\CryptoBot4Dummies\data\kaitousdt_1m_last14d.parquet  (3,265 rows | market_cap computed)
#     binance_pair          name symbol  current_price       market_cap  \
# 6        ADAUSDT       Cardano    ADA       0.736082 26,539,374,705.0
# 143      SUIUSDT           Sui    SUI           3.77 12,577,022,838.0
# 9        XLMUSDT       Stellar    XLM       0.284064  8,823,095,980.0
# 133     HBARUSDT        Hedera   HBAR        0.18914  7,993,775,795.0
# 3        BCHUSDT  Bitcoin Cash    BCH          388.9  7,723,815,067.0
#
#                                         klines_parquet   circulating_supply  \
# 6    C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 36,056,732,233.05023
# 143  C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 3,338,327,017.911665
# 9    C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 31,069,300,526.76352
# 133  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...  42,239,760,473.8114
# 3    C:\Users\saber\OneDrive\Documents\GitHub\Crypt...  19,870,490.52165078
#
#             total_supply           max_supply
# 6       45,000,000,000.0     45,000,000,000.0
# 143     10,000,000,000.0     10,000,000,000.0
# 9   50,001,786,892.81785 50,001,786,892.81785
# 133     50,000,000,000.0     50,000,000,000.0
# 3    19,870,809.27165078         21,000,000.0
# 📝  Master saved → binance_coingecko_market_caps.parquet

# %%
master_df
# Out:
#     binance_pair          name symbol  current_price       market_cap  \
# 6        ADAUSDT       Cardano    ADA       0.736082 26,539,374,705.0
# 143      SUIUSDT           Sui    SUI           3.77 12,577,022,838.0
# 9        XLMUSDT       Stellar    XLM       0.284064  8,823,095,980.0
# 133     HBARUSDT        Hedera   HBAR        0.18914  7,993,775,795.0
# 3        BCHUSDT  Bitcoin Cash    BCH          388.9  7,723,815,067.0
# ..           ...           ...    ...            ...              ...
# 155    TRUMPUSDT           NaN    NaN            NaN              NaN
# 156    NEIROUSDT           NaN    NaN            NaN              NaN
# 159        DUSDT           NaN    NaN            NaN              NaN
# 162        SUSDT           NaN    NaN            NaN              NaN
# 165     DATAUSDT           NaN    NaN            NaN              NaN
#
#                                         klines_parquet   circulating_supply  \
# 6    C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 36,056,732,233.05023
# 143  C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 3,338,327,017.911665
# 9    C:\Users\saber\OneDrive\Documents\GitHub\Crypt... 31,069,300,526.76352
# 133  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...  42,239,760,473.8114
# 3    C:\Users\saber\OneDrive\Documents\GitHub\Crypt...  19,870,490.52165078
# ..                                                 ...                  ...
# 155  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...                  NaN
# 156  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...                  NaN
# 159  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...                  NaN
# 162  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...                  NaN
# 165  C:\Users\saber\OneDrive\Documents\GitHub\Crypt...                  NaN
#
#             total_supply           max_supply
# 6       45,000,000,000.0     45,000,000,000.0
# 143     10,000,000,000.0     10,000,000,000.0
# 9   50,001,786,892.81785 50,001,786,892.81785
# 133     50,000,000,000.0     50,000,000,000.0
# 3    19,870,809.27165078         21,000,000.0
# ..                   ...                  ...
# 155                  NaN                  NaN
# 156                  NaN                  NaN
# 159                  NaN                  NaN
# 162                  NaN                  NaN
# 165                  NaN                  NaN
#
# [169 rows x 9 columns]

# %%
MORALIS_KEY = os.getenv("MORALIS_API_KEY", "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6IjRjMTZjNGVkLWVhZWMtNDVhZi04M2ZjLTM1YTlmZWE1ZjY1YSIsIm9yZ0lkIjoiNDQ3NjQ2IiwidXNlcklkIjoiNDYwNTcxIiwidHlwZUlkIjoiNDFlMTIwOWQtOTc2My00NDY0LThjMDItZjQ3ZGU4Njc2YjQxIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3NDc1MTkxMzYsImV4cCI6NDkwMzI3OTEzNn0.skoihqb--A5TzQVjDi3hwD3Blcq9UCCK1rnMme43Krs")

# %%
import requests
import pandas as pd
import vectorbt as vbt
import os
from datetime import datetime, timedelta

# ─── CONFIG ─────────────────────────────────────────────────────────────
BASE_URL   = "https://frontend-api-v3.pump.fun"
DATA_DIR   = "data"
RAW_DIR    = os.path.join(DATA_DIR, "raw")
os.makedirs(RAW_DIR, exist_ok=True)

DAYS_BACK    = 14       # backtest window
MAX_RECORDS  = 20_000   # max bars per mint
TIMEFRAME    = 1        # minutes per bar
API_LIMIT    = 1_000    # max bars per call
INIT_CASH    = 1_000
ALLOCATION   = 0.10
HOLD_MIN     = 15       # minutes to hold positions
QUANTILE     = 0.90     # dynamic threshold percentile

# ─── HELPERS ─────────────────────────────────────────────────────────────
def fetch_all_tokens():
    tokens, offset = [], 0
    while True:
        res = requests.get(f"{BASE_URL}/coins", params={"offset": offset, "limit": 100})
        res.raise_for_status()
        batch = res.json()
        if not batch:
            break
        tokens += batch
        offset += len(batch)
    return [t['mint'] for t in tokens if 'mint' in t]


def fetch_all_candles(mint):
    bars, offset = [], 0
    while True:
        params = {"timeframe": TIMEFRAME, "offset": offset, "limit": API_LIMIT}
        res = requests.get(f"{BASE_URL}/candlesticks/{mint}", params=params)
        res.raise_for_status()
        data = res.json()
        if not data or len(bars) >= MAX_RECORDS:
            break
        bars += data
        offset += len(data)
    if not bars:
        return pd.DataFrame()

    df = pd.DataFrame(bars)
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
    df.set_index('timestamp', inplace=True)
    df.sort_index(inplace=True)
    df = df[~df.index.duplicated(keep='first')]
    return df


def fetch_market_caps(mints):
    cutoff = datetime.utcnow() - timedelta(days=DAYS_BACK)
    markets = {}
    for mint in mints:
        raw_file = os.path.join(RAW_DIR, f"{mint}.parquet")
        if os.path.exists(raw_file):
            raw_df = pd.read_parquet(raw_file)
        else:
            raw_df = fetch_all_candles(mint)
            if raw_df.empty:
                continue
            raw_df.to_parquet(raw_file)

        window = raw_df[raw_df.index >= cutoff]
        if window.empty or 'close' not in window.columns:
            continue

        window['market_cap'] = window['close'] * 1e9
        markets[mint] = window[['market_cap']]
    return markets


def trading_signals_all(markets, quantile=QUANTILE, hold_minutes=HOLD_MIN):
    entries, exits = {}, {}
    for mint, df in markets.items():
        # dynamic threshold per symbol
        thresh = df['market_cap'].quantile(quantile)
        e = df['market_cap'] >= thresh
        e &= ~e.shift(1, fill_value=False)
        entries[mint] = e

        x = pd.Series(False, index=df.index)
        for t in df.index[e]:
            idx = df.index.searchsorted(t + timedelta(minutes=hold_minutes), side='left')
            if idx < len(df):
                x.iat[idx] = True
        exits[mint] = x
    return entries, exits


# ─── BACKTEST WITH DIAGNOSTICS ────────────────────────────────────────────
def backtest_all():
    mints   = fetch_all_tokens()
    markets = fetch_market_caps(mints)

    # Diagnostic: loaded symbols & sample stats
    print(f"Loaded symbols: {len(markets)}")
    if markets:
        first = next(iter(markets))
        df0 = markets[first]
        print(f"\nSample symbol: {first}")
        print(df0['market_cap'].describe())
        cap90 = df0['market_cap'].quantile(QUANTILE)
        print("90th percentile cap:", cap90)

    entries, exits = trading_signals_all(markets)

    # Diagnostic: one-symbol signal count
    if markets:
        one = first
        print(f"\n'{one}' entries: {entries[one].sum()}, exits: {exits[one].sum()}")

    # Build price & signal DataFrames
    prices = {m: caps['market_cap'] / 1e9 for m, caps in markets.items()}
    price_df = pd.concat(prices, axis=1).ffill().bfill().astype(float)

    ent_df = (
        pd.concat(entries, axis=1)
        .reindex(index=price_df.index, fill_value=False)
        .astype(bool)
    )
    ext_df = (
        pd.concat(exits, axis=1)
        .reindex(index=price_df.index, fill_value=False)
        .astype(bool)
    )
    price_df.columns.name = ent_df.columns.name = ext_df.columns.name = 'asset'

    # Run backtest
    pf = vbt.Portfolio.from_signals(
        close=price_df,
        entries=ent_df,
        exits=ext_df,
        init_cash=INIT_CASH,
        freq=f'{TIMEFRAME}min',
        fees=0.005,
        size=ALLOCATION,
        size_type='percent',
        cash_sharing=True,
    )

    # Results
    stats = pf.stats()
    print(f"\nTotal trades: {stats['Total Trades']}")
    return pf

if __name__ == "__main__":
    pf = backtest_all()
    stats = pf.stats()
    print("\nPortfolio stats:\n", stats)
    pf.plot().show()
# Out:
# Loaded symbols: 1030
#
# Sample symbol: HCaXo7UsMpRqGGwTMmJmgC9SQ19QTKAmZdN5tBoFpump
# count                  1.0
# mean    28.248202989374338
# std                    NaN
# min     28.248202989374338
# 25%     28.248202989374338
# 50%     28.248202989374338
# 75%     28.248202989374338
# max     28.248202989374338
# Name: market_cap, dtype: float64
# 90th percentile cap: 28.248202989374338
#
# 'HCaXo7UsMpRqGGwTMmJmgC9SQ19QTKAmZdN5tBoFpump' entries: 1, exits: 0
#
# Total trades: 1032
#
# Portfolio stats:
#  Start                               2025-05-18 02:12:00
# End                                 2025-05-18 03:47:00
# Period                                  0 days 01:36:00
# Start Value                                     1,000.0
# End Value                             911.8628469654944
# Total Return [%]                     -8.813715303450554
# Benchmark Return [%]                 -2.957023679458415
# Max Gross Exposure [%]                99.99999998569533
# Total Fees Paid                       5.139935603739097
# Max Drawdown [%]                       8.65743350334498
# Max Drawdown Duration                   0 days 01:35:00
# Total Trades                                       1032
# Total Closed Trades                                 140
# Total Open Trades                                   892
# Open Trade PnL                       -75.76718887901876
